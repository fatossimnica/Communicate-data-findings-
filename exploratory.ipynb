# %%
# Importing the necessary packages 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

df= pd.read_csv(r"C:\Users\Anna-Lena\Downloads\201902-fordgobike-tripdata.csv")
df
# Out:
#         duration_sec                start_time                  end_time  \
# 0              52185  2019-02-28 17:32:10.1450  2019-03-01 08:01:55.9750
# 1              42521  2019-02-28 18:53:21.7890  2019-03-01 06:42:03.0560
# 2              61854  2019-02-28 12:13:13.2180  2019-03-01 05:24:08.1460
# 3              36490  2019-02-28 17:54:26.0100  2019-03-01 04:02:36.8420
# 4               1585  2019-02-28 23:54:18.5490  2019-03-01 00:20:44.0740
# ...              ...                       ...                       ...
# 183407           480  2019-02-01 00:04:49.7240  2019-02-01 00:12:50.0340
# 183408           313  2019-02-01 00:05:34.7440  2019-02-01 00:10:48.5020
# 183409           141  2019-02-01 00:06:05.5490  2019-02-01 00:08:27.2200
# 183410           139  2019-02-01 00:05:34.3600  2019-02-01 00:07:54.2870
# 183411           271  2019-02-01 00:00:20.6360  2019-02-01 00:04:52.0580
#
#         start_station_id                                start_station_name  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183412 entries, 0 to 183411
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             183412 non-null  int64
#  1   start_time               183412 non-null  object
#  2   end_time                 183412 non-null  object
#  3   start_station_id         183215 non-null  float64
#  4   start_station_name       183215 non-null  object
#  5   start_station_latitude   183412 non-null  float64
#  6   start_station_longitude  183412 non-null  float64
#  7   end_station_id           183215 non-null  float64
#  8   end_station_name         183215 non-null  object
#  9   end_station_latitude     183412 non-null  float64
#  10  end_station_longitude    183412 non-null  float64
#  11  bike_id                  183412 non-null  int64
#  12  user_type                183412 non-null  object
# ...

# %%
# creating a copy of dataset before wrangling it 

df1=df.copy()

# %% [markdown]
# ### Data wrangling
#
#
# ##### Define
# 1. Converting the "df.duration_sec" to minutes
# 2. Rename "df.duration_sec" to "df.duration_min"
# 3. Rounding the numbers from the "duration_min" to two decimals.
#
# ###### Code

# %%
df1.duration_sec= df.duration_sec / 60 # Converting the "df.duration_sec" to minutes
df1.rename(columns={'duration_sec' : 'duration_min'},inplace=True) # Rename "df.duration_sec" to "df.duration_min"
df1['duration_min']=df1['duration_min'].apply(lambda x:round(x,2)) # Rounding the numbers from the "duration_min" to two decimals.

# %% [markdown]
# ###### Test

# %%
df1.head()
# Out:
#    duration_min                start_time                  end_time  \
# 0        869.75  2019-02-28 17:32:10.1450  2019-03-01 08:01:55.9750
# 1        708.68  2019-02-28 18:53:21.7890  2019-03-01 06:42:03.0560
# 2       1030.90  2019-02-28 12:13:13.2180  2019-03-01 05:24:08.1460
# 3        608.17  2019-02-28 17:54:26.0100  2019-03-01 04:02:36.8420
# 4         26.42  2019-02-28 23:54:18.5490  2019-03-01 00:20:44.0740
#
#    start_station_id                                start_station_name  \
# 0              21.0  Montgomery St BART Station (Market St at 2nd St)
# 1              23.0                     The Embarcadero at Steuart St
# 2              86.0                           Market St at Dolores St
# 3             375.0                           Grove St at Masonic Ave
# 4               7.0                               Frank H Ogawa Plaza
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# ...

# %% [markdown]
# #### Data exploration
#
#
# ###### 1. Duration mean
#
# It also interestion the average duration of the trips. After converting the varible from seconds to minutes the variable it is easier to read.
#
# Below we see the average duration of a trip in minutes.

# %%
# Average trip duration 
df1.duration_min.mean()
# Out:
# 12.101300732776364

# %% [markdown]
# ###### 1.1 Duration mean by "user_type"
#
# As the above analyses are interesting, on the other hand it is intriging to see how being a subscribe compares to being just a costumer when in comes to duration mean and day of the trip.

# %%
df1.groupby('user_type').mean().duration_min,
# Out:
# (user_type
#  Customer      23.874411
#  Subscriber    10.671055
#  Name: duration_min, dtype: float64,)

# %%
import seaborn as sns

ax = sns.barplot(x="user_type", y="duration_min", data=df1)

# %% [markdown]
# ##### 2. Day of the trip
#
# The first quastion we want to explore in what day are the most trips taken. In order to do that we need to extraxt the day from "start_time" variable.
#
# In the next step to make the analyses more readable we converted the numbers that represent week days into name of the day.

# %%
df1.start_time #overview of the column
# Out:
# 0         2019-02-28 17:32:10.1450
# 1         2019-02-28 18:53:21.7890
# 2         2019-02-28 12:13:13.2180
# 3         2019-02-28 17:54:26.0100
# 4         2019-02-28 23:54:18.5490
#                     ...
# 183407    2019-02-01 00:04:49.7240
# 183408    2019-02-01 00:05:34.7440
# 183409    2019-02-01 00:06:05.5490
# 183410    2019-02-01 00:05:34.3600
# 183411    2019-02-01 00:00:20.6360
# Name: start_time, Length: 183412, dtype: object

# %%
df1['day_of_trip'] = pd.DatetimeIndex(df['start_time']).day # extracting the day from "start_time" variable.

# %% [markdown]
# In the step below we converted the numbers into weekdays names to the variable and later the anlyses more understandable.

# %%
df1 = df1.replace({'day_of_trip': [1,8,15,22]}, 'monday')
df1 = df1.replace({'day_of_trip': [2,9,16,23]}, 'tuesday')
df1 = df1.replace({'day_of_trip': [3,10,17,24]}, 'wednesday')
df1 = df1.replace({'day_of_trip': [4,11,18,25]}, 'thursday')
df1 = df1.replace({'day_of_trip': [5,12,19,26]}, 'friday')
df1 = df1.replace({'day_of_trip': [6,13,20,27]}, 'saturday')
df1 = df1.replace({'day_of_trip': [7,14,21,28]}, 'sunday')

#1,8,15,22 = "monday"
#2,9,16,23 = "tuesday"
#3,10,17,24 = "wednesday"
#4,11,18,25 = "thursday"
#5,12,19,26 = "friday"
#6,13,20,27 = "saturday"
#7,14,21,28 = "sunday"

# %%
df1.day_of_trip.unique()
# Out:
# array(['sunday', 'saturday', 'friday', 'thursday', 'wednesday', 'tuesday',
#        'monday'], dtype=object)

# %% [markdown]
# ###### 2.1 Day of the trip by user_type
#
# As we see that all of the trips have started on the month of February, it was more interesting to see in what day of the week were the trips taken.
#
# On the first look we see a increas of the numbers trips taken during the weekend.

# %%
sb.countplot(data=df1, x='day_of_trip', hue='user_type', order=["monday", "tuesday","wednesday","thursday","friday","saturday","sunday"]);
